# %% [markdown]
# # 3. Desarrollo del Programa:
# Implementar el programa en Python para gestionar tareas utilizando solo listas y diccionarios.
#
# •	 Agregar al menos tres tareas distintas al programa utilizando el método insert() de la lista.

# %%
# Crear una lista para almacenar las tareas
tareas = []

# Agregar tareas utilizando el método insert() de la lista
tareas.insert(0, {"nombre": "Tarea 1", "prioridad": "Alta"})
tareas.insert(1, {"nombre": "Tarea 2", "prioridad": "Media"})
tareas.insert(2, {"nombre": "Tarea 3", "prioridad": "Baja"})

# Imprimir las tareas agregadas
print("Tareas agregadas:")
for tarea in tareas:
    print("Nombre:", tarea["nombre"], "- Prioridad:", tarea["prioridad"])
# Out:
# Tareas agregadas:
# Nombre: Tarea 1 - Prioridad: Alta
# Nombre: Tarea 2 - Prioridad: Media
# Nombre: Tarea 3 - Prioridad: Baja

# %% [markdown]
# •	 Eliminación de Tareas:
# Utilizar el método pop() de la lista para eliminar una de las tareas ingresadas.

# %%
tarea_eliminada = tareas.pop(1)

print("Se eleimino la tarea: ", tarea_eliminada)
# Out:
# Se eleimino la tarea:  {'nombre': 'Tarea 2', 'prioridad': 'Media'}

# %% [markdown]
# •	 Mostrar las Tareas:
# Imprimir en pantalla las tareas restantes almacenadas en la lista, accediendo directamente a los elementos mediante sus índices

# %%
print("Las tareas restantes son: ")
for i in range(len(tareas)):
    print(f"Tarea {i+1}: {tareas[i]}")
# Out:
# Las tareas restantes son:
# Tarea 1: {'nombre': 'Tarea 1', 'prioridad': 'Alta'}
# Tarea 2: {'nombre': 'Tarea 3', 'prioridad': 'Baja'}
